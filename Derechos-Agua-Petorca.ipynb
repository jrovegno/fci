# %%
from datetime import datetime
import pandas as pd
import pandas.io.data
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
pd.set_option('max_columns', 50)
# %matplotlib inline

# %%
run_console = False

# %%
if run_console:
    # %qtconsole

# %%
ddaa = pd.read_csv('Derechos_Concedidos_V_Region-xls-Petorca-WGS84-csv-V3.csv', index_col='Fecha de Resolución/ Envío al Juez/ Inscripción C.B.R.', parse_dates=True)

# %%
ddaa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2971 entries, 1913-11-12 00:00:00 to 1994-10-25 00:00:00
# Data columns (total 48 columns):
# LOCATION                                      2971 non-null object
# Código de
# Expediente                         2971 non-null object
# Uso del Agua                                  263 non-null object
# Naturaleza del
# Agua                          2967 non-null object
# Ejercicio del Derecho                         2971 non-null object
# Caudal
# Anual
# Prom                            2971 non-null float64
# Unidad de Caudal                              2971 non-null object
# Nombre Solicitante                            2971 non-null object
# N°
# Solicitud                                 2971 non-null int64
# Región,Provincia,Comuna                       2971 non-null object
# Unidad de Resolución/ Oficio/ C.B.R.          2966 non-null object
# N° Resolución/
# Oficio/ Fojas |
# N° CBR       2971 non-null object
# ...

# %%
ddaa.columns
# Out:
# Index([u'LOCATION', u'Código de \nExpediente', u'Uso del Agua', u'Naturaleza del \nAgua', u'Ejercicio del Derecho', u'Caudal \nAnual\nProm', u'Unidad de Caudal', u'Nombre Solicitante', u'N° \nSolicitud', u'Región,Provincia,Comuna', u'Unidad de Resolución/ Oficio/ C.B.R.', u'N° Resolución/ \nOficio/ Fojas | \nN° CBR', u'Tipo Derecho', u'Clasificación \nFuente', u'Cuenca', u'SubCuenca', u'SubSubCuenca', u'Fuente', u'Enero', u'Febrero', u'Marzo', u'Abril', u'Mayo', u'Junio', u'Julio', u'Agosto', u'Septiembre', u'Octubre', u'Noviembre', u'Diciembre', u'Caudal Ecológico\n(l/s)', u'¿Caudal Ecológico Promedio?', u'UTM \nNorte \nCaptación\n(m)', u'UTM \nEste \nCaptación\n(m)', u'Huso', u'Datum', u'Latitud \nCaptación', u'Longitud \nCaptación', u'Datum2', u'Referencia a puntos conocidos de captación', u'C.B.R.', u'Fojas', u'N° CBR', u'Año', u'Código Expediente\nAntiguo', u'¿Posee \nmás de un \npunto de captación?', u'N°', u'SIN_LOC'], dtype='object')

# %%
ddaa.sort(u'Caudal \nAnual\nProm', ascending=False).head(25)
# Out:
#                                                                                       LOCATION  \
# Fecha de Resolución/ Envío al Juez/ Inscripción C.B.R.
# 1913-11-12                                                               -32.250029,-70.933312
# 1915-02-15                                                               -32.250029,-70.933312
# 1999-11-16                                               -32.59909541949851,-71.30546144215435
# 1999-11-16                                               -32.59895638140796,-71.31302166192347
# 1999-11-16                                                -32.57229957693015,-71.3159578420655
# 1999-11-16                                               -32.59600333486564,-71.31667424764534
# 1999-11-16                                               -32.59259192682992,-71.31584075612558
# 2003-01-30                                               -32.22987883793083,-70.73319891846167
# ...

# %%
(len(ddaa.columns) - 15)*len(ddaa) < 100000
# Out:
# True

# %%
len(ddaa.columns)
# Out:
# 48

# %%
ddaa[u'Caudal \nAnual\nProm'].plot(figsize=(10, 10), style=['p'])

# %%
ddaa['1973':][u'Caudal \nAnual\nProm'].plot(figsize=(10, 10), style=['p'])

# %%
ddaa[u'Ejercicio del Derecho'].value_counts()
# Out:
# Permanente y Continuo            2857
# Perm. y Cont. y Provisionales      51
# Permanente y Discontinuo           26
# Eventual y Continuo                13
# Eventual y Discontinuo             11
# Permanente y Alternado             11
# Eventual y Alternado                2
# dtype: int64

# %%
ddaa[u'Uso del Agua'].value_counts()
# Out:
# Riego                               247
# Bebida/Uso Domestico/Saneamiento     16
# dtype: int64

# %%
ddaa[u'Naturaleza del \nAgua'].value_counts()
# Out:
# Subterranea                2766
# Superficial y Corriente     165
# Superficial                  36
# dtype: int64

# %%
ddaa[u'Nombre Solicitante'].value_counts().head(25)
# Out:
# AGRICOLA PALTUNCHO LTDA                             50
# AGRICOLA PETORCA S.A.                               48
# MARTIN IGNACIO HENRIQUEZ LARRAIN                    45
# HUMBERTO EINAR JUAN BENEDETTI ROSENQVIST            36
# AGRICOLA RIO TINTO S.A.                             34
# SOCIEDAD AGRICOLA LOS GRANEROS LIMITADA             34
# AGRICOLA PULLACON LIMITADA                          32
# AGRO FRUTILLAR LIMITADA                             31
# COMPAÑIA AGRICOLA Y MINERA LOS ANGELES S.A.         23
# AGRICOLA OLIVOS DE HUAQUEN S.A.                     21
# COOPERATIVA CAMPESINA SANTA VICTORIA LTDA.          20
# EMPRESA DE OBRAS SANITARIAS DE VALPARAISO S.A.      20
# AGRICOLA LA MARTINA LIMITADA                        19
# JUAN WENKE WILLIAMS                                 18
# AGRICOLA EL SOBRANTE LIMITADA.                      18
# AGRICOLA GRANADA FR LIMITADA                        16
# AGRICOLA CHALACO S.A.                               16
# ...

# %%
grp = ddaa.groupby(u'Nombre Solicitante')
caudales = grp[u'Caudal \nAnual\nProm'].sum()
caudales_desc = caudales.order(ascending=False).head(20)

# %%
ddaa[u'Caudal \nAnual\nProm'].describe()
# Out:
# count    2971.000000
# mean       10.638982
# std        94.552638
# min         0.010000
# 25%         1.000000
# 50%         2.000000
# 75%         6.000000
# max      3500.000000
# dtype: float64

# %%
ddaa[u'Caudal \nAnual\nProm'].sum()
# Out:
# 31608.414399999881

# %%
caudales_desc.plot(kind='pie', figsize=(10, 10))
